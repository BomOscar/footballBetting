# %%
import json as js
import pandas as pd
from datetime import datetime

# %%
with open("finalTestingFotMob.json") as f:
    jsonData = js.load(f)
type(jsonData)
# Out:
# list

# %%
for index, jd in enumerate(jsonData, start=1):
    print("\n%%%%%%%%%%%%%%%%%%--%%%%%%%-------------Processing JSON object", index,"----------------%%%%%%%--%%%%%%%%%%%%%%%%%%%%\n")
    seasonNumber = jd["details"]['selectedSeason']
    print(seasonNumber)
    seasonName = jd["details"]['name']
    print(seasonName)
    
    
    ###111111111111111111111111111111111111111111
    ###Printing all DAta from table0DataTableKeys
    tbb =[]
#     for i in jd['table'][0]['data']['table'].keys():
#         matches = jd['table'][0]['data']['table'][i]
#         print(f"---------{i.upper()}----------")
#         for match in matches:
#             str1, str2 = match['scoresStr'].replace("-", "_").split('_')
#             print(f"""\n{match['name']}\n{match['shortName']}\n{match['id']}\n
#                     {match['pageUrl']}\n{match['played']}\n{match['wins']}\n
#                     {match['draws']}\n{match['losses']}\n{str1}\n{str2}\n{match['goalConDiff']}\n
#                     {match['pts']}\n{match['idx']}
#                     """)   


    ###222222222222222222222222222222222222222222
    ###Printing all Data from Table0TeamFormKeys
    tbss = []
#     for i in jd['table'][0]['teamForm'].keys():
#         tforms = jd['table'][0]['teamForm'][i]
#         print(f"_________--------------_________{i}")
#         for tform in tforms:
#             matchLink  =tform['linkToMatch']
#             teamUrl = tform['teamPageUrl']
#             result = tform['result']
#             resultStr = tform['resultString']
#             utcTime = tform['tooltipText']['utcTime']
#             Hteam = tform['tooltipText']['homeTeam']
#             ATeam = tform['tooltipText']['awayTeam']
#             HTID = tform['tooltipText']['homeTeamId']
#             HScore = tform['tooltipText']['homeScore']
#             AScore = tform['tooltipText']['awayScore']
#             ATID = tform['tooltipText']['awayTeamId']
#             Tsc1,Tsc2 = tform['score'].replace("-","_").split("_")
#             formattedTime =  datetime.strptime(utcTime, '%Y-%m-%dT%H:%M:%S%fZ').strftime('%Y-%m-%d').replace("-", "_")
#             formattedTime2 =  datetime.strptime(utcTime, '%Y-%m-%dT%H:%M:%S%fZ')
#             hour = formattedTime2.strftime('%H')
#             minute = formattedTime2.strftime('%M')
#             day = formattedTime2.strftime('%A')
#             weekDay = formattedTime2.weekday()
#             year = formattedTime2.year
#             monthID = formattedTime2.month
#             dayDate = formattedTime2.day
#             monthName = formattedTime2.strftime('%B')

#             print(f"\n{matchLink}\n{teamUrl}\n{result}\n{resultStr}\n{formattedTime}\n{hour}\n{minute}\n{Hteam}\n{HTID}\n{HScore}\n{ATeam}\n{ATID}\n{AScore}\n{Tsc1}\n{Tsc2}") 


    ###3333333333333333333333333333333333333333333333333
    ###Printing all Data from OverviewTable0DataTableKeys
    tbss = []
#     for i in jd['overview']['table'][0]['data']['table'].keys():
#         tforms = jd['overview']['table'][0]['data']['table'][i]
#         print(f"__________------------------{i.upper()}")
#         for tform in tforms:
#             form = tform['scoresStr'].replace( '-', '_')
#             col1, col2 = form.split('_')
#             print(f"""\n{tform['name']}\n{tform['id']}\n{tform['played']}\n{tform['wins']}\n{tform['pageUrl']}
#             {tform['draws']}\n{tform['losses']}\n{col1}\n{col2}\n{tform[ 'goalConDiff']}\n{tform['pts']}""")
    
    ###4444444444444444444444444444444444444444444444444
   ###Printing overviewTable0teamFormData
    ts = []
#     for i in jd['overview']['table'][0]['teamForm'].keys():
#         tforms = jd['overview']['table'][0]['teamForm'][i]
#         print(f"-----------______________------------{i}")
#         for tform in tforms:
#             matchLink  =tform['linkToMatch']
#             teamUrl = tform['teamPageUrl']
#             result = tform['result']
#             resultStr = tform['resultString']
#             utcTime = tform['tooltipText']['utcTime']
#             Hteam = tform['tooltipText']['homeTeam']
#             ATeam = tform['tooltipText']['awayTeam']
#             HTID = tform['tooltipText']['homeTeamId']
#             HScore = tform['tooltipText']['homeScore']
#             AScore = tform['tooltipText']['awayScore']
#             ATID = tform['tooltipText']['awayTeamId']
#             Tsc1,Tsc2 = tform['score'].replace("-","_").split("_")
#             formattedTime =  datetime.strptime(utcTime, '%Y-%m-%dT%H:%M:%S%fZ').strftime('%Y-%m-%d').replace("-", "_")
#             formattedTime2 =  datetime.strptime(utcTime, '%Y-%m-%dT%H:%M:%S%fZ')
#             hour = formattedTime2.strftime('%H')
#             minute = formattedTime2.strftime('%M')
#             day = formattedTime2.strftime('%A')
#             weekDay = formattedTime2.weekday()
#             year = formattedTime2.year
#             monthID = formattedTime2.month
#             dayDate = formattedTime2.day
#             monthName = formattedTime2.strftime('%B')

#             print(f"\n{matchLink}\n{teamUrl}\n{result}\n{resultStr}\n{formattedTime}\n{hour}\n{minute}\n{Hteam}\n{HTID}\n{HScore}\n{ATeam}\n{ATID}\n{AScore}\n{Tsc1}\n{Tsc2}") 


    ###5555555555555555555555555555555555555555555555555555
    ###Printing DAta from overviewLeagueOverviewMatchesData
    ovv = []
#     for i in jd['overview']['leagueOverviewMatches']:
#         LeagOvervMatchID = i['id']
#         LeagOvervMatchPagUrl = i['pageUrl']
#         OppId = i['opponent']['id']
#         OppNam = i['opponent']['name']
#         OppScor = i['opponent']['score']
#         HomId = i['home']['id']
#         HomName = i['home']['name']
#         HomScor = i['home']['score']
#         AwayId = i['away']['id']
#         AwayNam = i['away']['name']
#         AwayScor = i['away']['score']
#         StartTime = i['status']['utcTime']
#         Scor1,Scor2 = i['status']['scoreStr'].replace("-","_").split("_")
#         formattedTime =  datetime.strptime(StartTime, '%Y-%m-%dT%H:%M:%S.%fZ').strftime('%Y-%m-%d %H:%M:%S').replace("-", "_")
#         formattedTime2 =  datetime.strptime(formattedTime, '%Y_%m_%d %H:%M:%S')
#         hour = formattedTime2.strftime('%H')
#         minute = formattedTime2.strftime('%M')
#         day = formattedTime2.strftime('%A')
#         weekDay = formattedTime2.weekday()
#         year = formattedTime2.year
#         monthID = formattedTime2.month
#         dayDate = formattedTime2.day
#         monthName = formattedTime2.strftime('%B')
       
#         print(f"""\n{LeagOvervMatchID}\n{LeagOvervMatchPagUrl}\n{OppId}\n{OppNam}\n{OppScor}\n{HomId}\n{HomName}\n{HomScor}\n
#         {AwayId}\n{AwayNam}\n{AwayScor}\n{hour}\n{minute}\n{Scor1}\n{Scor2}\n{StartTime}\n""")    

    ###666666666666666666666666666666666666666666
    ###Printind Data from matchesAllMatchesData
    allmat = []
#     for i in jd['matches']['allMatches']:
#         pageUrl = i['pageUrl']
#         MatchId = i['id']
#         HomeTeam = i['home']['name']
#         HTName = i['home']['shortName']
#         HTID = i['home']['id']
#         AwayTeam = i['away']['name']
#         ATName = i['away']['name']
#         ATID = i['away']['id']
#         StaTime = i['status']['utcTime']
#         Scr1,Scr2 = i['status']['scoreStr'].replace("-","_").split("_")
#         formattedTime =  datetime.strptime(StaTime, '%Y-%m-%dT%H:%M:%S.%fZ').strftime('%Y-%m-%d %H:%M:%S').replace("-", "_")
#         formattedTime2 =  datetime.strptime(formattedTime, '%Y_%m_%d %H:%M:%S')
#         hour = formattedTime2.strftime('%H')
#         minute = formattedTime2.strftime('%M')

#         print(f"\n{pageUrl}\n{MatchId}\n{HomeTeam}\n{HTName}\n{HTID}\n{AwayTeam}\n{ATName}\n{ATID}\n{formattedTime}\n{hour}\n{minute}\n{Scr1}\n{Scr2}\n")

# %%
tbb
# Out:
# [{'Key': 'ALL'},
#  'AFC Bournemouth',
#  'Bournemouth',
#  8678,
#  '/teams/8678/overview/afc-bournemouth',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
#  0,
#  0,
#  1,
#  '#2AD572',
#  'Arsenal',
#  'Arsenal',
#  9825,
#  '/teams/9825/overview/arsenal',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
#  0,
#  0,
#  2,
#  '#2AD572',
#  'Aston Villa',
#  'Aston Villa',
#  10252,
#  '/teams/10252/overview/aston-villa',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
#  0,
#  0,
#  3,
#  '#2AD572',
#  'Brentford',
#  'Brentford',
#  9937,
#  '/teams/9937/overview/brentford',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
#  0,
#  0,
#  4,
#  '#2AD572',
#  'Brighton & Hove Albion',
#  'Brighton',
#  10204,
#  '/teams/10204/overview/brighton--hove-albion',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
#  0,
#  0,
#  5,
#  '#0046A7',
#  'Burnley',
#  'Burnley',
#  8191,
#  '/teams/8191/overview/burnley',
#  None,
#  None,
#  0,
#  0,
#  0,
#  0,
#  '0-0',
# ...
